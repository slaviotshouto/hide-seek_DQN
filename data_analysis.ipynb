# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm

import pandas as pd
from plot_helper import plot_only_mean_rewards, plot_interaction

# %% [markdown]
# ## Hiders/seekers regular 100fov2000 games

# %%
# hiders,1352
# seekers,648

mean_scores_hiders = []
hider_values = []

with open('pandas_plots/hider_rewards.csv', 'r') as f_obj:
    l = f_obj.read().splitlines()
    total_reward = 0
    for idx, value in enumerate(l):
        total_reward += int(value)
        hider_values.append(int(value))
        dev_by = idx+1
        mean_scores_hiders.append(total_reward/dev_by)

mean_scores_seekers = []
seeker_values = []
with open('pandas_plots/seeker_rewards.csv', 'r') as f_obj:
    l = f_obj.read().splitlines()
    total_reward = 0
    for idx, value in enumerate(l):
        total_reward += int(value)
        seeker_values.append(int(value))
        dev_by = idx+1
        mean_scores_seekers.append(total_reward/dev_by)

plot_only_mean_rewards(mean_scores_hiders, mean_scores_seekers)

# %%
with open('pandas_plots/hiders_interaction.csv', 'r') as f_obj:
    l = f_obj.read().splitlines()
    hider_interaction = []
    for i in l:
        hider_interaction.append(int(i))

with open('pandas_plots/seekers_interaction.csv', 'r') as f_obj:
    l = f_obj.read().splitlines()
    seeker_interaction = []
    for i in l:
        seeker_interaction.append(int(i))
    
with open('pandas_plots/random_hider_rewards.csv', 'r') as f_obj:
    l = f_obj.read().splitlines()
    random_hider_reward = []
    for i in l:
        random_hider_reward.append(int(i))
        
with open('pandas_plots/random_seeker_rewards.csv', 'r') as f_obj:
    l = f_obj.read().splitlines()
    random_seeker_reward = []
    for i in l:
        random_seeker_reward.append(int(i))

with open('pandas_plots/random_hiders_interaction.csv', 'r') as f_obj:
    l = f_obj.read().splitlines()
    random_hider_interaction = []
    for i in l:
        random_hider_interaction.append(int(i))
        
with open('pandas_plots/random_seekers_interaction.csv', 'r') as f_obj:
    l = f_obj.read().splitlines()
    random_seeker_interaction = []
    for i in l:
        random_seeker_interaction.append(int(i))

# %%
print(len(hider_interaction))
print(len(seeker_interaction))
print(len(hider_values), len(seeker_values))
print(len(mean_scores_hiders),  len(mean_scores_seekers))
# Out:
# 2000
# 2000
# 2000 2000
# 2000 2000

# %%
import numpy as np
hider_int_devalues = np.array(hider_interaction, dtype=np.double)
hider_int_devalues[hider_int_devalues==0] = np.nan


plot_interaction(hider_int_devalues, "Hider Item Interaction")
df_hider_interaction = pd.DataFrame(hider_interaction)
df_hider_interaction.describe()
# Out:
#                  0
# count  2000.000000
# mean      0.328500
# std       3.660914
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max      86.000000

# %%
plot_interaction(seeker_interaction, "Seeker Item Interaction")
df_seeker_interaction = pd.DataFrame(seeker_interaction)
df_seeker_interaction.describe()
# Out:
#                 0
# count  2000.00000
# mean      0.89500
# std       6.86167
# min       0.00000
# 25%       0.00000
# 50%       0.00000
# 75%       0.00000
# max     143.00000

# %%
plt.clf()
plt.title('Object Interactions')
plt.xlabel('Number of Games')
plt.ylabel('Interactions')    
plt.plot(mean_scores_hiders, label='Hider mean score')
#plt.plot(mean_scores_seekers, label='Seeker mean score')
plt.scatter([i for i in range(1, 2001)], hider_interaction, label='Hider Item Interaction')
plt.legend(loc='upper right')
plt.show(block=False)

# %%
df_hider_scores = pd.DataFrame(hider_values)
df_hider_scores.describe()
# Out:
#                  0
# count  2000.000000
# mean    277.250000
# std     220.457332
# min    -501.000000
# 25%      49.000000
# 50%     387.000000
# 75%     477.000000
# max     501.000000

# %%
df_seeker_scores = pd.DataFrame(seeker_values)
df_seeker_scores.describe()
# Out:
#                  0
# count  2000.000000
# mean   -277.250000
# std     220.457332
# min    -501.000000
# 25%    -477.000000
# 50%    -387.000000
# 75%     -49.000000
# max     501.000000

# %%
# Hiders are inherently favored in a randomized environment
df_random_hider_scores = pd.DataFrame(random_hider_reward)
df_random_hider_scores.describe()
# Out:
#                 0
# count  100.000000
# mean   472.940000
# std     43.818224
# min    317.000000
# 25%    461.000000
# 50%    498.000000
# 75%    501.000000
# max    501.000000

# %%
df_random_seeker_scores = pd.DataFrame(random_seeker_reward)
df_random_seeker_scores.describe()
# Out:
#                 0
# count  100.000000
# mean  -472.940000
# std     43.818224
# min   -501.000000
# 25%   -501.000000
# 50%   -498.000000
# 75%   -461.000000
# max   -317.000000

# %%
df_random_hider_interaction = pd.DataFrame(random_hider_interaction)
df_random_hider_interaction.describe()
# Out:
#                 0
# count  100.000000
# mean     9.080000
# std     11.750504
# min      0.000000
# 25%      0.000000
# 50%      4.000000
# 75%     14.000000
# max     46.000000

# %%
df_random_seeker_interaction = pd.DataFrame(random_seeker_interaction)
df_random_seeker_interaction.describe()
# Out:
#                 0
# count  100.000000
# mean    14.960000
# std     13.711987
# min      0.000000
# 25%      1.500000
# 50%     12.500000
# 75%     25.250000
# max     46.000000

# %% [markdown]
# ### Regular fov 300

# %%
# hiders,1540 = 77%
# seekers,460 = 23%

hider_mean_reg300fov = []
hider_values_reg300fov = []

with open('pandas_plots/hider_rewardsregularfov300.csv', 'r') as f_obj:
    l = f_obj.read().splitlines()
    total_reward = 0
    for idx, value in enumerate(l):
        total_reward += int(value)
        hider_values_reg300fov.append(int(value))
        dev_by = idx+1
        hider_mean_reg300fov.append(total_reward/dev_by)

seeker_mean_reg300fov = []
seeker_values_reg300fov = []
with open('pandas_plots/seeker_rewardsregularfov300.csv', 'r') as f_obj:
    l = f_obj.read().splitlines()
    total_reward = 0
    for idx, value in enumerate(l):
        total_reward += int(value)
        seeker_values_reg300fov.append(int(value))
        dev_by = idx+1
        seeker_mean_reg300fov.append(total_reward/dev_by)

plot_only_mean_rewards(hider_mean_reg300fov, seeker_mean_reg300fov)
#plot_only_mean_rewards(hider_values_reg300fov, seeker_values_reg300fov)

# %%
mean_scores_hiders, mean_scores_seekers
hider_mean_reg300fov, seeker_mean_reg300fov

plt.clf()
plt.title('Global DQN after 2000 Episodes')
plt.xlabel('Number of Games')
plt.ylabel('Reward')
plt.plot(mean_scores_hiders, label='H mean score 100')
plt.plot(mean_scores_seekers, label='S mean score 100')
plt.plot(hider_mean_reg300fov, label='H mean score 300')
plt.plot(seeker_mean_reg300fov, label='S mean score 300')
plt.legend(loc='upper right')
plt.show(block=False)

# %%
with open('pandas_plots/hiders_interactionregularfov300.csv', 'r') as f_obj:
    l = f_obj.read().splitlines()
    hider_interaction_reg300fov = []
    for i in l:
        hider_interaction_reg300fov.append(int(i))

with open('pandas_plots/seekers_interactionregularfov300.csv', 'r') as f_obj:
    l = f_obj.read().splitlines()
    seeker_interaction_reg300fov = []
    for i in l:
        seeker_interaction_reg300fov.append(int(i))

# %%
print(len(hider_interaction_reg300fov))
print(len(seeker_interaction_reg300fov))
print(len(hider_values_reg300fov), len(seeker_values_reg300fov))
print(len(hider_mean_reg300fov),  len(seeker_mean_reg300fov))
# Out:
# 2000
# 2000
# 2000 2000
# 2000 2000

# %%
plot_interaction(hider_interaction_reg300fov, "Hider Item Interaction")
df_hider_interaction = pd.DataFrame(hider_interaction_reg300fov)
df_hider_interaction.describe()
# Out:
#                  0
# count  2000.000000
# mean      1.207500
# std      16.759501
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max     581.000000

# %%
plot_interaction(seeker_interaction_reg300fov, "Seeker Item Interaction")
df_seeker_interaction = pd.DataFrame(seeker_interaction_reg300fov)
df_seeker_interaction.describe()
# Out:
#                  0
# count  2000.000000
# mean      0.372000
# std       5.517049
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max     150.000000

# %%
import numpy as np
hider_int_values = np.array(hider_interaction_reg300fov, dtype=np.double)
hider_int_values[hider_int_values==0] = np.nan

plt.clf()
plt.title('Object Interactions DQN 300 Fov')
plt.xlabel('Number of Games')
plt.ylabel('Interactions')    
plt.plot(hider_mean_reg300fov, label='Hider mean score')
#plt.plot(mean_scores_seekers, label='Seeker mean score')
plt.scatter([i for i in range(1, 2001)], hider_int_values, label='Hider Item Interaction')
plt.legend(loc='upper right')
plt.show(block=False)

# %%
df_hider_scores = pd.DataFrame(hider_values_reg300fov)
df_hider_scores.describe()
# Out:
#                  0
# count  2000.000000
# mean    279.870000
# std     232.267855
# min    -491.000000
# 25%      23.750000
# 50%     420.000000
# 75%     475.000000
# max     501.000000

# %%
df_seeker_scores = pd.DataFrame(seeker_values_reg300fov)
df_seeker_scores.describe()
# Out:
#                  0
# count  2000.000000
# mean   -279.870000
# std     232.267855
# min    -501.000000
# 25%    -475.000000
# 50%    -420.000000
# 75%     -23.750000
# max     491.000000

# %% [markdown]
# ### Regular fov 500

# %%
# hiders,999 49.95%
# seekers,1001 50.05%

hider_mean_reg500fov = []
hider_values_reg500fov = []

with open('pandas_plots/hider_rewardsregularfov500.csv', 'r') as f_obj:
    l = f_obj.read().splitlines()
    total_reward = 0
    for idx, value in enumerate(l):
        total_reward += int(value)
        hider_values_reg500fov.append(int(value))
        dev_by = idx+1
        hider_mean_reg500fov.append(total_reward/dev_by)

seeker_mean_reg500fov = []
seeker_values_reg500fov = []
with open('pandas_plots/seeker_rewardsregularfov500.csv', 'r') as f_obj:
    l = f_obj.read().splitlines()
    total_reward = 0
    for idx, value in enumerate(l):
        total_reward += int(value)
        seeker_values_reg500fov.append(int(value))
        dev_by = idx+1
        seeker_mean_reg500fov.append(total_reward/dev_by)

plot_only_mean_rewards(hider_mean_reg500fov, seeker_mean_reg500fov)
#plot_only_mean_rewards(hider_values_reg300fov, seeker_values_reg300fov)

# %%
with open('pandas_plots/hiders_interactionregularfov500.csv', 'r') as f_obj:
    l = f_obj.read().splitlines()
    hider_interaction_reg500fov = []
    for i in l:
        hider_interaction_reg500fov.append(int(i))

with open('pandas_plots/seekers_interactionregularfov500.csv', 'r') as f_obj:
    l = f_obj.read().splitlines()
    seeker_interaction_reg500fov = []
    for i in l:
        seeker_interaction_reg500fov.append(int(i))

# %%
print(len(hider_interaction_reg500fov))
print(len(seeker_interaction_reg500fov))
print(len(hider_values_reg500fov), len(seeker_values_reg500fov))
print(len(hider_mean_reg500fov),  len(seeker_mean_reg500fov))
# Out:
# 2000
# 2000
# 2000 2000
# 2000 2000

# %%
plot_interaction(hider_interaction_reg500fov, "Hider Item Interaction")
df_hider_interaction = pd.DataFrame(hider_interaction_reg500fov)
df_hider_interaction.describe()
# Out:
#                  0
# count  2000.000000
# mean      1.192500
# std      17.326008
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max     558.000000

# %%
plot_interaction(seeker_interaction_reg500fov, "Seeker Item Interaction")
df_seeker_interaction = pd.DataFrame(seeker_interaction_reg500fov)
df_seeker_interaction.describe()

plt.clf()
plt.title('Object Interactions')
plt.xlabel('Number of Games')
plt.ylabel('Interactions')    
plt.plot(hider_mean_reg500fov, label='Hider mean score')
#plt.plot(mean_scores_seekers, label='Seeker mean score')
plt.scatter([i for i in range(1, 2001)], hider_interaction_reg500fov, label='Hider Item Interaction')
plt.legend(loc='upper right')
plt.show(block=False)

# %%
plt.clf()
plt.title('Object Interactions')
plt.xlabel('Number of Games')
plt.ylabel('Interactions')    
plt.plot(hider_mean_reg500fov, label='Hider mean score')
#plt.plot(mean_scores_seekers, label='Seeker mean score')
plt.scatter([i for i in range(1, 2001)], hider_interaction_reg500fov, label='Hider Item Interaction')
plt.legend(loc='upper right')
plt.show(block=False)

# %%
df_hider_scores = pd.DataFrame(hider_values_reg500fov)
df_hider_scores.describe()
# Out:
#                 0
# count  2000.00000
# mean     49.81400
# std     195.33122
# min    -501.00000
# 25%     -35.00000
# 50%       0.00000
# 75%      77.00000
# max     501.00000

# %%
df_seeker_scores = pd.DataFrame(seeker_values_reg500fov)
df_seeker_scores.describe()
# Out:
#                 0
# count  2000.00000
# mean    -49.81400
# std     195.33122
# min    -501.00000
# 25%     -77.00000
# 50%       0.00000
# 75%      35.00000
# max     501.00000

# %% [markdown]
# ### Situated fov 100

# %%
#hiders,1929
#seekers,71

hider_mean_situated = []
hider_values_situated = []

with open('pandas_plots/hider_rewards_situated.csv', 'r') as f_obj:
    l = f_obj.read().splitlines()
    total_reward = 0
    for idx, value in enumerate(l):
        total_reward += int(value)
        hider_values_situated.append(int(value))
        dev_by = idx+1
        hider_mean_situated.append(total_reward/dev_by)

seeker_mean_situated = []
seeker_values_situated = []
with open('pandas_plots/seeker_rewards_situated.csv', 'r') as f_obj:
    l = f_obj.read().splitlines()
    total_reward = 0
    for idx, value in enumerate(l):
        total_reward += int(value)
        seeker_values_situated.append(int(value))
        dev_by = idx+1
        seeker_mean_situated.append(total_reward/dev_by)

plot_only_mean_rewards(hider_mean_situated, seeker_mean_situated)

# %%
with open('pandas_plots/hiders_interaction_situated.csv', 'r') as f_obj:
    l = f_obj.read().splitlines()
    hider_interaction_situated = []
    for i in l:
        hider_interaction_situated.append(int(i))

with open('pandas_plots/seekers_interaction_situated.csv', 'r') as f_obj:
    l = f_obj.read().splitlines()
    seeker_interaction_situated = []
    for i in l:
        seeker_interaction_situated.append(int(i))

# %%
print(len(hider_interaction_situated))
print(len(seeker_interaction_situated))
print(len(hider_values_situated), len(seeker_values_situated))
print(len(hider_mean_situated),  len(seeker_mean_situated))
# Out:
# 2000
# 2000
# 2000 2000
# 2000 2000

# %%
plot_interaction(hider_interaction_situated, "Hider Item Interaction")
df_hider_interaction = pd.DataFrame(hider_interaction_situated)
df_hider_interaction.describe()
# Out:
#                  0
# count  2000.000000
# mean      0.621500
# std       8.943055
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max     359.000000

# %%
#plot_interaction(seeker_interaction_situated, "Seeker Item Interaction")
df_seeker_interaction = pd.DataFrame(seeker_interaction_situated)
df_seeker_interaction.describe()

plt.clf()
plt.title('Object Interactions Situated')
plt.xlabel('Number of Games')
plt.ylabel('Interactions')    
#plt.plot(seeker_mean_situated, label='Seeker mean score')
#plt.plot(mean_scores_seekers, label='Seeker mean score')
plt.scatter([i for i in range(1, 2001)], hider_interaction_situated, label='Hider Item Interaction')
plt.scatter([i for i in range(1, 2001)], seeker_interaction_situated, label='Seeker Item Interaction')
plt.legend(loc='upper right')
plt.show(block=False)

# %%
plt.clf()
plt.title('Object Interactions')
plt.xlabel('Number of Games')
plt.ylabel('Interactions')    
plt.plot(seeker_mean_situated, label='Seeker mean score')
#plt.plot(mean_scores_seekers, label='Seeker mean score')
plt.scatter([i for i in range(1, 2001)], seeker_interaction_situated, label='Seeker Item Interaction')
plt.legend(loc='upper right')
plt.show(block=False)

# %%
df_hider_scores = pd.DataFrame(hider_values_situated)
df_hider_scores.describe()
# Out:
#                  0
# count  2000.000000
# mean    447.188500
# std     127.166264
# min    -359.000000
# 25%     491.000000
# 50%     501.000000
# 75%     501.000000
# max     501.000000

# %%
df_seeker_scores = pd.DataFrame(seeker_values_situated)
df_seeker_scores.describe()
# Out:
#                  0
# count  2000.000000
# mean   -447.188500
# std     127.166264
# min    -501.000000
# 25%    -501.000000
# 50%    -501.000000
# 75%    -491.000000
# max     359.000000

# %% [markdown]
# ### Heuristics fov100

# %%
#hiders,1560 78%
#seekers,440 22%

hider_mean_heur100fov = []
hider_values_heur100fov = []

with open('pandas_plots/hider_rewardsheuristicsfov100.csv', 'r') as f_obj:
    l = f_obj.read().splitlines()
    total_reward = 0
    for idx, value in enumerate(l):
        total_reward += int(value)
        hider_values_heur100fov.append(int(value))
        dev_by = idx+1
        hider_mean_heur100fov.append(total_reward/dev_by)

seeker_mean_heur100fov = []
seeker_values_heur100fov = []
with open('pandas_plots/seeker_rewardsheuristicsfov100.csv', 'r') as f_obj:
    l = f_obj.read().splitlines()
    total_reward = 0
    for idx, value in enumerate(l):
        total_reward += int(value)
        seeker_values_heur100fov.append(int(value))
        dev_by = idx+1
        seeker_mean_heur100fov.append(total_reward/dev_by)

plot_only_mean_rewards(hider_mean_heur100fov, seeker_mean_heur100fov)
#plot_only_mean_rewards(hider_values_reg300fov, seeker_values_reg300fov)

# %%
with open('pandas_plots/hiders_interactionheuristicsfov100.csv', 'r') as f_obj:
    l = f_obj.read().splitlines()
    hider_interaction_heur100fov = []
    for i in l:
        hider_interaction_heur100fov.append(int(i))

with open('pandas_plots/seekers_interactionheuristicsfov100.csv', 'r') as f_obj:
    l = f_obj.read().splitlines()
    seeker_interaction_heur100fov = []
    for i in l:
        seeker_interaction_heur100fov.append(int(i))

# %%
print(len(hider_interaction_heur100fov))
print(len(seeker_interaction_heur100fov))
print(len(hider_values_heur100fov), len(seeker_values_heur100fov))
print(len(hider_mean_heur100fov),  len(seeker_mean_heur100fov))
# Out:
# 2000
# 2000
# 2000 2000
# 2000 2000

# %%
plot_interaction(hider_interaction_heur100fov, "Hider Item Interaction")
df_hider_interaction = pd.DataFrame(hider_interaction_heur100fov)
df_hider_interaction.describe()
# Out:
#                  0
# count  2000.000000
# mean      9.465000
# std      11.494731
# min       0.000000
# 25%       0.000000
# 50%       6.000000
# 75%      15.000000
# max      67.000000

# %%
plot_interaction(seeker_interaction_heur100fov, "Seeker Item Interaction")
df_seeker_interaction = pd.DataFrame(seeker_interaction_heur100fov)
df_seeker_interaction.describe()
# Out:
#                  0
# count  2000.000000
# mean     11.945000
# std      13.441961
# min       0.000000
# 25%       0.000000
# 50%       8.000000
# 75%      19.000000
# max      86.000000

# %%
plt.clf()
plt.title('Object Interactions')
plt.xlabel('Number of Games')
plt.ylabel('Interactions')    
plt.plot(hider_mean_heur100fov, label='Hider mean score')
#plt.plot(mean_scores_seekers, label='Seeker mean score')
plt.scatter([i for i in range(1, 2001)], hider_interaction_heur100fov, label='Hider Item Interaction')
plt.legend(loc='upper right')
plt.show(block=False)

# %%
df_hider_scores = pd.DataFrame(hider_values_heur100fov)
df_hider_scores.describe()
# Out:
#                  0
# count  2000.000000
# mean    396.872000
# std     155.344229
# min    -359.000000
# 25%     349.750000
# 50%     501.000000
# 75%     501.000000
# max     501.000000

# %%
df_seeker_scores = pd.DataFrame(seeker_values_heur100fov)
df_seeker_scores.describe()
# Out:
#                  0
# count  2000.000000
# mean   -396.872000
# std     155.344229
# min    -501.000000
# 25%    -501.000000
# 50%    -501.000000
# 75%    -349.750000
# max     359.000000

# %% [markdown]
# ### Heuristics fov 300

# %%
#hiders,768 38.4% 
#seekers,1232 61.6%

hider_mean_heur300fov = []
hider_values_heur300fov = []

with open('pandas_plots/hider_rewardsheuristicsfov300.csv', 'r') as f_obj:
    l = f_obj.read().splitlines()
    total_reward = 0
    for idx, value in enumerate(l):
        total_reward += int(value)
        hider_values_heur300fov.append(int(value))
        dev_by = idx+1
        hider_mean_heur300fov.append(total_reward/dev_by)

seeker_mean_heur300fov = []
seeker_values_heur300fov = []
with open('pandas_plots/seeker_rewardsheuristicsfov300.csv', 'r') as f_obj:
    l = f_obj.read().splitlines()
    total_reward = 0
    for idx, value in enumerate(l):
        total_reward += int(value)
        seeker_values_heur300fov.append(int(value))
        dev_by = idx+1
        seeker_mean_heur300fov.append(total_reward/dev_by)

plot_only_mean_rewards(hider_mean_heur300fov, seeker_mean_heur300fov)

# %%
with open('pandas_plots/hiders_interactionheuristicsfov300.csv', 'r') as f_obj:
    l = f_obj.read().splitlines()
    hider_interaction_heur300fov = []
    for i in l:
        hider_interaction_heur300fov.append(int(i))

with open('pandas_plots/seekers_interactionheuristicsfov300.csv', 'r') as f_obj:
    l = f_obj.read().splitlines()
    seeker_interaction_heur300fov = []
    for i in l:
        seeker_interaction_heur300fov.append(int(i))

# %%
print(len(hider_interaction_heur300fov))
print(len(seeker_interaction_heur300fov))
print(len(hider_values_heur300fov), len(seeker_values_heur300fov))
print(len(hider_mean_heur300fov),  len(seeker_mean_heur300fov))
# Out:
# 2000
# 2000
# 2000 2000
# 2000 2000

# %%
plot_interaction(hider_interaction_heur300fov, "Hider Item Interaction")
df_hider_interaction = pd.DataFrame(hider_interaction_heur300fov)
df_hider_interaction.describe()
# Out:
#                  0
# count  2000.000000
# mean      4.884000
# std       8.911692
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       6.000000
# max      76.000000

# %%
plot_interaction(seeker_interaction_heur300fov, "Seeker Item Interaction")
df_seeker_interaction = pd.DataFrame(seeker_interaction_heur300fov)
df_seeker_interaction.describe()
# Out:
#                  0
# count  2000.000000
# mean      4.817000
# std       9.311867
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       6.000000
# max      63.000000

# %%
plt.clf()
plt.title('Object Interactions')
plt.xlabel('Number of Games')
plt.ylabel('Interactions')    
plt.plot(hider_mean_heur300fov, label='Hider mean score')
#plt.plot(mean_scores_seekers, label='Seeker mean score')
plt.scatter([i for i in range(1, 2001)], hider_interaction_heur300fov, label='Hider Item Interaction')
plt.legend(loc='upper right')
plt.show(block=False)

# %%
df_hider_scores = pd.DataFrame(hider_values_heur300fov)
df_hider_scores.describe()
# Out:
#                  0
# count  2000.000000
# mean    -15.645000
# std     240.828466
# min    -499.000000
# 25%     -82.500000
# 50%     -14.000000
# 75%     119.000000
# max     501.000000

# %%
df_seeker_scores = pd.DataFrame(seeker_values_heur300fov)
df_seeker_scores.describe()
# Out:
#                  0
# count  2000.000000
# mean     15.645000
# std     240.828466
# min    -501.000000
# 25%    -119.000000
# 50%      14.000000
# 75%      82.500000
# max     499.000000

# %% [markdown]
# ### Heuristics fov 500

# %%
# hiders,538 26.9%
# seekers,1462 73.1%

hider_mean_heur500fov = []
hider_values_heur500fov = []

with open('pandas_plots/hider_rewardsheuristicsfov500.csv', 'r') as f_obj:
    l = f_obj.read().splitlines()
    total_reward = 0
    for idx, value in enumerate(l):
        total_reward += int(value)
        hider_values_heur500fov.append(int(value))
        dev_by = idx+1
        hider_mean_heur500fov.append(total_reward/dev_by)

seeker_mean_heur500fov = []
seeker_values_heur500fov = []
with open('pandas_plots/seeker_rewardsheuristicsfov500.csv', 'r') as f_obj:
    l = f_obj.read().splitlines()
    total_reward = 0
    for idx, value in enumerate(l):
        total_reward += int(value)
        seeker_values_heur500fov.append(int(value))
        dev_by = idx+1
        seeker_mean_heur500fov.append(total_reward/dev_by)

plot_only_mean_rewards(hider_mean_heur500fov, seeker_mean_heur500fov)
#plot_only_mean_rewards(hider_values_reg300fov, seeker_values_reg300fov)

# %%
with open('pandas_plots/hiders_interactionheuristicsfov500.csv', 'r') as f_obj:
    l = f_obj.read().splitlines()
    hider_interaction_heur500fov = []
    for i in l:
        hider_interaction_heur500fov.append(int(i))

with open('pandas_plots/seekers_interactionheuristicsfov500.csv', 'r') as f_obj:
    l = f_obj.read().splitlines()
    seeker_interaction_heur500fov = []
    for i in l:
        seeker_interaction_heur500fov.append(int(i))

# %%
print(len(hider_interaction_heur500fov))
print(len(seeker_interaction_heur500fov))
print(len(hider_values_heur500fov), len(seeker_values_heur500fov))
print(len(hider_mean_heur500fov),  len(seeker_mean_heur500fov))
# Out:
# 2000
# 2000
# 2000 2000
# 2000 2000

# %%
plot_interaction(hider_interaction_heur500fov, "Hider Item Interaction")
df_hider_interaction = pd.DataFrame(hider_interaction_heur500fov)
df_hider_interaction.describe()
# Out:
#                  0
# count  2000.000000
# mean     10.055000
# std       8.204245
# min       0.000000
# 25%       4.000000
# 50%       9.000000
# 75%      14.000000
# max      50.000000

# %%
plot_interaction(seeker_interaction_heur500fov, "Seeker Item Interaction")
df_seeker_interaction = pd.DataFrame(seeker_interaction_heur500fov)
df_seeker_interaction.describe()
# Out:
#                  0
# count  2000.000000
# mean      2.625000
# std       6.731644
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max      63.000000

# %%
plt.clf()
plt.title('Object Interactions')
plt.xlabel('Number of Games')
plt.ylabel('Interactions')    
plt.plot(hider_mean_heur500fov, label='Hider mean score')
#plt.plot(mean_scores_seekers, label='Seeker mean score')
plt.scatter([i for i in range(1, 2001)], hider_interaction_heur500fov, label='Hider Item Interaction')
plt.legend(loc='upper right')
plt.show(block=False)

# %%
df_hider_scores = pd.DataFrame(hider_values_heur500fov)
df_hider_scores.describe()
# Out:
#                  0
# count  2000.000000
# mean   -102.788000
# std     190.484254
# min    -501.000000
# 25%    -153.500000
# 50%     -51.000000
# 75%     -14.750000
# max     501.000000

# %%
df_seeker_scores = pd.DataFrame(seeker_values_heur500fov)
df_seeker_scores.describe()
# Out:
#                  0
# count  2000.000000
# mean    102.788000
# std     190.484254
# min    -501.000000
# 25%      14.750000
# 50%      51.000000
# 75%     153.500000
# max     501.000000

# %% [markdown]
# ### FOV 300 RETESTED (5 Times)

# %%
# hiders,1190 = 59.50%
# seekers,810 = 40.50%

hider_mean_RETESTED_regularfov300 = []
hider_values_RETESTED_regularfov300 = []

with open('pandas_plots/hider_rewardsRETESTED_regularfov300.csv', 'r') as f_obj:
    l = f_obj.read().splitlines()
    total_reward = 0
    for idx, value in enumerate(l):
        total_reward += int(value)
        hider_values_RETESTED_regularfov300.append(int(value))
        dev_by = idx+1
        hider_mean_RETESTED_regularfov300.append(total_reward/dev_by)

seeker_mean_RETESTED_regularfov300 = []
seeker_values_RETESTED_regularfov300 = []
with open('pandas_plots/seeker_rewardsRETESTED_regularfov300.csv', 'r') as f_obj:
    l = f_obj.read().splitlines()
    total_reward = 0
    for idx, value in enumerate(l):
        total_reward += int(value)
        seeker_values_RETESTED_regularfov300.append(int(value))
        dev_by = idx+1
        seeker_mean_RETESTED_regularfov300.append(total_reward/dev_by)

plot_only_mean_rewards(hider_mean_RETESTED_regularfov300, seeker_mean_RETESTED_regularfov300)
#plot_only_mean_rewards(hider_values_reg300fov, seeker_values_reg300fov)

# %%
mean_scores_hiders, mean_scores_seekers
hider_mean_RETESTED_regularfov300, seeker_mean_RETESTED_regularfov300

plt.clf()
plt.title('Global DQN after 2000 Episodes')
plt.xlabel('Number of Games')
plt.ylabel('Reward')
plt.plot(mean_scores_seekers, label='S mean reward 100')
plt.plot(seeker_mean_RETESTED_regularfov300, label='S mean reward 300')
plt.plot(seeker_mean_reg500fov, label='S mean reward 500')
plt.legend(loc='lower right')
plt.show(block=False)

# %%
mean_scores_hiders, mean_scores_seekers
hider_mean_RETESTED_regularfov300, seeker_mean_RETESTED_regularfov300

plt.clf()
plt.title('Heuristics models after 2000 Episodes')
plt.xlabel('Number of Games')
plt.ylabel('Reward')
plt.plot(seeker_mean_heur100fov, label='S mean reward 100')
plt.plot(seeker_mean_heur300fov, label='S mean reward 300')
plt.plot(seeker_mean_heur500fov, label='S mean reward 500')
plt.legend(loc='center right')
plt.show(block=False)

# %%
mean_scores_hiders, mean_scores_seekers
hider_mean_RETESTED_regularfov300, seeker_mean_RETESTED_regularfov300

plt.clf()
plt.title('Global DQN after 2000 Episodes')
plt.xlabel('Number of Games')
plt.ylabel('Reward')
plt.plot(mean_scores_hiders, label='H mean reward 100')
plt.plot(hider_mean_RETESTED_regularfov300, label='H mean reward 300')
plt.plot(hider_mean_reg500fov, label='H mean reward 500')
plt.legend(loc='upper right')
plt.show(block=False)

# %%
with open('pandas_plots/hiders_interactionRETESTED_regularfov300.csv', 'r') as f_obj:
    l = f_obj.read().splitlines()
    hider_interaction_RETESTED_regularfov300 = []
    for i in l:
        hider_interaction_RETESTED_regularfov300.append(int(i))

with open('pandas_plots/seekers_interactionRETESTED_regularfov300.csv', 'r') as f_obj:
    l = f_obj.read().splitlines()
    seeker_interaction_RETESTED_regularfov300 = []
    for i in l:
        seeker_interaction_RETESTED_regularfov300.append(int(i))

# %%
print(len(hider_interaction_RETESTED_regularfov300))
print(len(seeker_interaction_RETESTED_regularfov300))
print(len(hider_values_RETESTED_regularfov300), len(seeker_values_RETESTED_regularfov300))
print(len(hider_mean_RETESTED_regularfov300),  len(seeker_mean_RETESTED_regularfov300))
# Out:
# 2000
# 2000
# 2000 2000
# 2000 2000

# %%
plot_interaction(hider_interaction_RETESTED_regularfov300, "Hider Item Interaction")
df_hider_interaction = pd.DataFrame(hider_interaction_RETESTED_regularfov300)
df_hider_interaction.describe()
# Out:
#                  0
# count  2000.000000
# mean      2.042000
# std      25.811361
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max     562.000000

# %%
plot_interaction(seeker_interaction_RETESTED_regularfov300, "Seeker Item Interaction")
df_seeker_interaction = pd.DataFrame(seeker_interaction_RETESTED_regularfov300)
df_seeker_interaction.describe()
# Out:
#                  0
# count  2000.000000
# mean      0.787000
# std      11.987764
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max     459.000000

# %%
import numpy as np
hider_int_values = np.array(hider_interaction_RETESTED_regularfov300, dtype=np.double)
hider_int_values[hider_int_values==0] = np.nan

plt.clf()
plt.title('Object Interactions DQN 300 Fov')
plt.xlabel('Number of Games')
plt.ylabel('Interactions')    
plt.plot(hider_mean_RETESTED_regularfov300, label='Hider mean score')
#plt.plot(mean_scores_seekers, label='Seeker mean score')
plt.scatter([i for i in range(1, 2001)], hider_int_values, label='Hider Item Interaction')
plt.legend(loc='upper right')
plt.show(block=False)

# %%
df_hider_scores = pd.DataFrame(hider_values_RETESTED_regularfov300)
df_hider_scores.describe()
# Out:
#                  0
# count  2000.000000
# mean    156.034500
# std     208.056978
# min    -465.000000
# 25%      -3.000000
# 50%      77.000000
# 75%     395.500000
# max     501.000000

# %%
df_seeker_scores = pd.DataFrame(seeker_values_RETESTED_regularfov300)
df_seeker_scores.describe()
# Out:
#                  0
# count  2000.000000
# mean   -156.034500
# std     208.056978
# min    -501.000000
# 25%    -395.500000
# 50%     -77.000000
# 75%       3.000000
# max     465.000000

# %%
hider_mean_reg500fov

plt.clf()
plt.title('Global DQN after 2000 Episodes')
plt.xlabel('Number of Games')
plt.ylabel('Reward')
plt.plot(hider_mean_RETESTED_regularfov300, label='H mean score FOV 300')
plt.plot(hider_mean_reg300fov, label='H mean score FOV 300 outlier')
#plt.plot(seeker_mean_RETESTED_regularfov300, label='H mean score 300')
#plt.plot(seeker_mean_reg300fov, label='H mean score outlier')
plt.legend(loc='upper right')
plt.show(block=False)
